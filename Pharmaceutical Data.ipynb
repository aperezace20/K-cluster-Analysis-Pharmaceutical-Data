# %% [markdown]
# # Week 2 Exercise: Pharmaceutical Data

# %% [markdown]
# #### Q1: In your opinion, what is the purpose to perform cluster analysis on the pharmaceutical company data?
#
# Before we perform cluster analysis, we need to understand the purpose to create clusters on this dataset.
#
# ### Step 1: Read and preprocess the data
# #### Import pandas library, use pd.read_csv() to read the data
# ##### Code for reference:
#
# import pandas as pd
#
# pharm = pd.read_csv('your path here/Pharmaceuticals.csv')

# %%
import pandas as pd

pharm = pd.read_csv('C:/Users/apere/OneDrive/Desktop/CIS 508/Pharmaceuticals.csv')

# %% [markdown]
# #### Use .head() to have a look at the data

# %%
pharm.head()
# Out:
#   Symbol                 Name  Market_Cap  Beta  PE_Ratio   ROE   ROA  \
# 0    ABT  Abbott Laboratories       68.44  0.32      24.7  26.4  11.8
# 1    AGN       Allergan, Inc.        7.58  0.41      82.5  12.9   5.5
# 2    AHM         Amersham plc        6.30  0.46      20.7  14.9   7.8
# 3    AZN      AstraZeneca PLC       67.63  0.52      21.5  27.4  15.4
# 4    AVE              Aventis       47.16  0.32      20.1  21.8   7.5
#
#    Asset_Turnover  Leverage  Rev_Growth  Net_Profit_Margin  \
# 0             0.7      0.42        7.54               16.1
# 1             0.9      0.60        9.16                5.5
# 2             0.9      0.27        7.05               11.2
# 3             0.9      0.00       15.00               18.0
# 4             0.6      0.34       26.81               12.9
#
#   Median_Recommendation Location Exchange
# 0          Moderate Buy       US     NYSE
# 1          Moderate Buy   CANADA     NYSE
# 2            Strong Buy       UK     NYSE
# ...

# %% [markdown]
# #### Q2: When you perform k-means cluster analysis, what data type of the features is used?
#
# Note you don't need any analysis to answer this question, but you are encouraged to take a look at data type using **.dtypes**.
#
# ##### code for reference
# pharm.dtypes

# %%
pharm.head()
# Out:
#   Symbol                 Name  Market_Cap  Beta  PE_Ratio   ROE   ROA  \
# 0    ABT  Abbott Laboratories       68.44  0.32      24.7  26.4  11.8
# 1    AGN       Allergan, Inc.        7.58  0.41      82.5  12.9   5.5
# 2    AHM         Amersham plc        6.30  0.46      20.7  14.9   7.8
# 3    AZN      AstraZeneca PLC       67.63  0.52      21.5  27.4  15.4
# 4    AVE              Aventis       47.16  0.32      20.1  21.8   7.5
#
#    Asset_Turnover  Leverage  Rev_Growth  Net_Profit_Margin  \
# 0             0.7      0.42        7.54               16.1
# 1             0.9      0.60        9.16                5.5
# 2             0.9      0.27        7.05               11.2
# 3             0.9      0.00       15.00               18.0
# 4             0.6      0.34       26.81               12.9
#
#   Median_Recommendation Location Exchange
# 0          Moderate Buy       US     NYSE
# 1          Moderate Buy   CANADA     NYSE
# 2            Strong Buy       UK     NYSE
# ...

# %% [markdown]
# #### Q3: In order to perform cluster analysis, we need to select the variables from 3rd column to 11th column in pharmaceutical data. Which of the following is correct to do the selection?
#
# To answer this question, we need to select the 3rd column (Market Cap) to the 11th column (Net_Profit_Margin) (the numerical variables) using .iloc[ ]
#
# ##### Code for reference:
#
# X= pharm.iloc[ , ].values

# %%
X= pharm.iloc[:,2:11].values

# %%
X
# Out:
# array([[ 6.8440e+01,  3.2000e-01,  2.4700e+01,  2.6400e+01,  1.1800e+01,
#          7.0000e-01,  4.2000e-01,  7.5400e+00,  1.6100e+01],
#        [ 7.5800e+00,  4.1000e-01,  8.2500e+01,  1.2900e+01,  5.5000e+00,
#          9.0000e-01,  6.0000e-01,  9.1600e+00,  5.5000e+00],
#        [ 6.3000e+00,  4.6000e-01,  2.0700e+01,  1.4900e+01,  7.8000e+00,
#          9.0000e-01,  2.7000e-01,  7.0500e+00,  1.1200e+01],
#        [ 6.7630e+01,  5.2000e-01,  2.1500e+01,  2.7400e+01,  1.5400e+01,
#          9.0000e-01,  0.0000e+00,  1.5000e+01,  1.8000e+01],
#        [ 4.7160e+01,  3.2000e-01,  2.0100e+01,  2.1800e+01,  7.5000e+00,
#          6.0000e-01,  3.4000e-01,  2.6810e+01,  1.2900e+01],
#        [ 1.6900e+01,  1.1100e+00,  2.7900e+01,  3.9000e+00,  1.4000e+00,
#          6.0000e-01,  0.0000e+00, -3.1700e+00,  2.6000e+00],
#        [ 5.1330e+01,  5.0000e-01,  1.3900e+01,  3.4800e+01,  1.5100e+01,
#          9.0000e-01,  5.7000e-01,  2.7000e+00,  2.0600e+01],
# ...

# %% [markdown]
# #### Q4: Which function can we use to perform standardization before a cluster analysis?
#
# Now we standardize the features selected above.
# ##### Code for reference:
#
# from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler()
#
# pharm_std = scaler.fit_transform()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

pharm_std = scaler.fit_transform(X)
pharm_std
# Out:
# array([[ 1.88642282e-01, -8.21040576e-01, -4.78668159e-02,
#          4.10803822e-02,  2.47578717e-01, -5.24754233e-16,
#         -2.17335702e-01, -5.40800775e-01,  6.32054993e-02],
#        [-8.75518007e-01, -4.61835324e-01,  3.58342950e+00,
#         -8.75950197e-01, -9.65556995e-01,  9.45313187e-01,
#          1.87358364e-02, -3.90551348e-01, -1.59203499e+00],
#        [-8.97899295e-01, -2.62276851e-01, -2.99167599e-01,
#         -7.40093815e-01, -5.22666180e-01,  9.45313187e-01,
#         -4.14061984e-01, -5.86246589e-01, -7.01952839e-01],
#        [ 1.74479124e-01, -2.28066827e-02, -2.48907443e-01,
#          1.09008573e-01,  9.40799124e-01,  9.45313187e-01,
#         -7.68169291e-01,  1.51088563e-01,  3.59899549e-01],
#        [-1.83446626e-01, -8.21040576e-01, -3.36862717e-01,
#         -2.71389297e-01, -5.80434547e-01, -4.72656593e-01,
#         -3.22256386e-01,  1.24642544e+00, -4.36489742e-01],
#        [-7.12554256e-01,  2.33198330e+00,  1.53173811e-01,
# ...

# %% [markdown]
# ### Step 2: Perform K-means cluster analysis

# %% [markdown]
# #### Q5: For the given data, how many clusters are recommended to perform k-means cluster analysis obtained by the elbow method?

# %% [markdown]
# To answer this question, you need to create elbow visualization to get the optimal k. Let's say we want k to be ranged in **(1,8)**. And when we use Kmeans() we set **init ='k-means++', max_iter=300,  n_init=10, random_state=0**.
#
# ##### Code for reference
#
# from sklearn.cluster import KMeans
#
# wcss=[]
#
# for i in range(1,8):
#
#      kmeans = KMeans(n_clusters=i, init ='k-means++', max_iter=300,  n_init=10,random_state=0 )
#
#      kmeans.fit()
#
#      wcss.append(kmeans.inertia_)
#
#
# import matplotlib.pyplot as plt
#
# plt.plot(range(1,8),wcss, marker = "o")
#
# plt.title('The Elbow Method Graph')
#
# plt.xlabel('Number of clusters')
#
# plt.ylabel('WCSS')
#
# plt.show()

# %%
from sklearn.cluster import KMeans
wcss=[]

for i in range(1,8):

 kmeans = KMeans(n_clusters=i, init ='k-means++', max_iter=300,  n_init=10,random_state=0 )

 kmeans.fit(pharm_std)

 wcss.append(kmeans.inertia_)
# Out:
# C:\Users\apere\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,8),wcss, marker = "o")

plt.title('The Elbow Method Graph')

plt.xlabel('Number of clusters')

plt.ylabel('WCSS')

plt.show()

# %% [markdown]
# #### Now let's perform k-means cluster analysis using KMeans() by specifying the identifed k with **init ='k-means++', max_iter=300,  n_init=10, random_state=0**.
# ##### Code for reference
# km = KMeans(n_clusters= , init= 'k-means++', max_iter= 300, n_init= 10, random_state= 0).fit()

# %%
km = KMeans(n_clusters= 2, init= 'k-means++', max_iter= 300, n_init= 10, random_state= 0).fit(pharm_std)

# %% [markdown]
# #### Q6: Which cluster label does Abbott Laboratories belong to?
# To answer this question, first you need assign the data points into the clusters using **predict**,Then create a new column called **label** to save the cluster labels for each data point in the data.
#
# ##### Code for reference:
# clusters = km.fit_predict()
#
# pharm['label'] = clusters

# %%
clusters = km.fit_predict(pharm_std)
clusters
# Out:
# array([0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 0, 1, 0, 1, 0, 0, 0, 1, 0, 1, 0])

# %%
pharm['label'] = clusters
pharm
# Out:
#    Symbol                                Name  Market_Cap  Beta  PE_Ratio  \
# 0     ABT                 Abbott Laboratories       68.44  0.32      24.7
# 1     AGN                      Allergan, Inc.        7.58  0.41      82.5
# 2     AHM                        Amersham plc        6.30  0.46      20.7
# 3     AZN                     AstraZeneca PLC       67.63  0.52      21.5
# 4     AVE                             Aventis       47.16  0.32      20.1
# 5     BAY                            Bayer AG       16.90  1.11      27.9
# 6     BMY        Bristol-Myers Squibb Company       51.33  0.50      13.9
# 7    CHTT                        Chattem, Inc        0.41  0.85      26.0
# 8     ELN               Elan Corporation, plc        0.78  1.08       3.6
# 9     LLY               Eli Lilly and Company       73.84  0.18      27.9
# 10    GSK                 GlaxoSmithKline plc      122.11  0.35      18.0
# 11    IVX                    IVAX Corporation        2.60  0.65      19.9
# ...

# %% [markdown]
# ### Step 3: Interpret and visualize the clusters
#
# #### Q7: Which variable has the most distinctive power to separate the clusters in the data?
#
# To answer the questions, we need to create the parallel coordinates. To do this,
# 1. First create a data frame to save centroids in each cluster in terms of the variables used to perform the k-means cluster analysis.
#
# ##### Code for reference
# centroids = pd.DataFrame(km.cluster_centers_, columns = [ ])

# %%
centroids = pd.DataFrame(km.cluster_centers_, columns = ['Market_Cap','Beta','PE_Ratio','ROE','ROA','Asset_Turnover','Leverage','Rev_Growth','Net_Profit_Margin' ])
centroids
# Out:
#    Market_Cap      Beta  PE_Ratio       ROE       ROA  Asset_Turnover  \
# 0    0.690012 -0.367499 -0.283176  0.672813  0.855022        0.472657
# 1   -0.759013  0.404248  0.311493 -0.740094 -0.940524       -0.519922
#
#    Leverage  Rev_Growth  Net_Profit_Margin
# 0 -0.341333   -0.297383           0.699181
# 1  0.375466    0.327122          -0.769099

# %% [markdown]
# 2. Then, add a new column called "cluster" to indicate the index of the clusters for each set of the centroids.
# ##### Code for reference:
# centroids['cluster'] = ['Cluster {}'.format(i) for i in centroids.index]

# %%
centroids['cluster'] = ['Cluster {}'.format(i) for i in centroids.index]
centroids
# Out:
#    Market_Cap      Beta  PE_Ratio       ROE       ROA  Asset_Turnover  \
# 0    0.690012 -0.367499 -0.283176  0.672813  0.855022        0.472657
# 1   -0.759013  0.404248  0.311493 -0.740094 -0.940524       -0.519922
#
#    Leverage  Rev_Growth  Net_Profit_Margin    cluster
# 0 -0.341333   -0.297383           0.699181  Cluster 0
# 1  0.375466    0.327122          -0.769099  Cluster 1

# %% [markdown]
# 3. Then, create parallel coordinates to visualize the centroids for each cluster
#
# ##### Code for reference
# import matplotlib.pyplot as plt
#
# from pandas.plotting import parallel_coordinates
#
# parallel_coordinates(centroids, class_column='cluster', colormap='Dark2', linewidth=5)
#
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#
# plt.figure(figsize=(10,6))

# %%
import matplotlib.pyplot as plt

# %%
from pandas.plotting import parallel_coordinates

# %%
parallel_coordinates(centroids, class_column='cluster', colormap='Dark2', linewidth=5)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.figure(figsize=(10,6))

# %% [markdown]
# #### Q8: Based on the information given by parallel coordinates plot, which statement is true about the clusters?
#
# #### Q9: Which statement is True about the clusters in terms of "Market_Cap" and "Net_Profit_Margin"?
#
# To answer this question, we can visualize the clusters using "Market_Cap" and "Net_Profit_Margin" using **seaborn**.
#
# ##### Code for reference
# import seaborn as sns
#
# sns.lmplot(data= pharm, y= 'Market_Cap', x='Net_Profit_Margin', hue= 'label',fit_reg = False, legend = True)

# %%
import seaborn as sns

# %%
sns.lmplot(data= pharm, y= 'Market_Cap', x='Net_Profit_Margin', hue= 'label',fit_reg = False, legend = True)

# %% [markdown]
# #### Q10. Based on your analysis, what could be concluded?
